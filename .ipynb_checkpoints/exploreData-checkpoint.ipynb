# %%
import pandas as pd 
import numpy as np 
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('productResult.xlsx')
df
# Out:
#       Customer_ID  result_rank provider_Nm  product_name dummy_quote_value  \
# 0              37            1  Provider A    Product 64           377.089
# 1              37            2  Provider A  Product 3160           60.4049
# 2              37            3  Provider A    Product 56           309.119
# 3              37            4  Provider A   Product 552           224.304
# 4              37            5  Provider A  Product 3292           79.1503
# 5              37            6  Provider A    Product 76           401.601
# 6              37            7  Provider B  Product 1412           263.217
# 7              37            8  Provider A    Product 84           525.587
# 8              37            9  Provider B  Product 3164           556.828
# 9              57            1  Provider A    Product 56           229.212
# 10             57            2  Provider A   Product 552           63.3663
# 11             57            3  Provider A    Product 84           651.466
# 12             57            4  Provider B  Product 3532            782.26
# 13             57            5  Provider B  Product 1412           653.106
# 14             57            6  Provider B  Product 3164           698.661
# 15             57            7  Provider B  Product 1412           58.2317
# 16             57            8  Provider B  Product 3164           239.248
# 17             60            1  Provider A  Product 3160           174.154
# 18             60            2  Provider A  Product 3292           576.061
# 19             60            3  Provider A    Product 64           176.726
# 20             60            4  Provider A    Product 56           445.284
# 21             60            5  Provider B  Product 3532            194.45
# 22             60            6  Provider A   Product 552           76.0832
# 23             60            7  Provider A    Product 76           660.539
# 24             60            8  Provider B  Product 1412           186.792
# 25             60            9  Provider A    Product 84           60.6906
# 26             60           10  Provider B  Product 3164           801.484
# 27            113            1  Provider A  Product 3160           779.049
# 28            113            2  Provider A    Product 56           60.3624
# 29            113            3  Provider A   Product 552           589.123
# ...           ...          ...         ...           ...               ...
# 4657      4057382            5  Provider A    Product 84           705.928
# 4658      4057382            6  Provider B  Product 3164           136.547
# 4659      4057776            1  Provider A  Product 3160           106.784
# 4660      4057776            2  Provider A    Product 64           442.178
# 4661      4057776            3  Provider A    Product 56           206.934
# 4662      4057776            4  Provider A   Product 552           743.057
# 4663      4057776            5  Provider A    Product 76           231.184
# 4664      4057776            6  Provider A    Product 84           910.825
# 4665      4057776            7  Provider B  Product 1412           945.424
# 4666      4058416            1  Provider A  Product 3160           348.981
# 4667      4058416            2  Provider B  Product 1412           206.917
# 4668      4058416            3  Provider A    Product 64            534.29
# 4669      4058416            4  Provider A    Product 56           443.355
# 4670      4058416            5  Provider A   Product 552           626.822
# 4671      4058416            6  Provider A    Product 76           270.405
# 4672      4058416            7  Provider A    Product 84           677.782
# 4673      4060624            1  Provider A  Product 3160           729.696
# 4674      4060624            2  Provider A  Product 3292           724.373
# 4675      4060624            3  Provider A    Product 56           486.755
# 4676      4060624            4  Provider A   Product 552           232.443
# 4677      4060624            5  Provider A    Product 84            698.02
# 4678      4060624            6  Provider B  Product 1412            394.02
# 4679      4060624            7  Provider B  Product 3164           185.673
# 4680      4062897            1  Provider A    Product 64           158.756
# 4681      4062897            2  Provider B  Product 1412           MISSING
# 4682      4062897            3  Provider A    Product 56            287.82
# 4683      4062897            4  Provider A   Product 552           220.771
# 4684      4062897            5  Provider A    Product 76           759.641
# 4685      4062897            6  Provider A    Product 84           79.2413
# 4686      4062897            7  Provider B  Product 3164           693.729
#
#       Sale_made Sale_source
# 0             0         NaN
# 1             0         NaN
# 2             0         NaN
# 3             0         NaN
# 4             0         NaN
# 5             0         NaN
# 6             0         NaN
# 7             0         NaN
# 8             0         NaN
# 9             0         NaN
# 10            1      online
# 11            0         NaN
# 12            1      online
# 13            0         NaN
# 14            0         NaN
# 15            0         NaN
# 16            0         NaN
# 17            0         NaN
# 18            0         NaN
# 19            0         NaN
# 20            0         NaN
# 21            0         NaN
# 22            0         NaN
# 23            1  callcentre
# 24            0         NaN
# 25            0         NaN
# 26            0         NaN
# 27            0         NaN
# 28            0         NaN
# 29            0         NaN
# ...         ...         ...
# 4657          0         NaN
# 4658          0         NaN
# 4659          0         NaN
# 4660          0         NaN
# 4661          0         NaN
# 4662          0         NaN
# 4663          0         NaN
# 4664          0         NaN
# 4665          0         NaN
# 4666          0         NaN
# 4667          0         NaN
# 4668          0         NaN
# 4669          0         NaN
# 4670          0         NaN
# 4671          0         NaN
# 4672          0         NaN
# 4673          0         NaN
# 4674          0         NaN
# 4675          0         NaN
# 4676          0         NaN
# 4677          0         NaN
# 4678          0         NaN
# 4679          0         NaN
# 4680          0         NaN
# 4681          0         NaN
# 4682          0         NaN
# 4683          0         NaN
# 4684          0         NaN
# 4685          0         NaN
# 4686          0         NaN
#
# [4687 rows x 7 columns]

# %%
df.describe()
# Out:
#         Customer_ID  result_rank    Sale_made
# count  4.687000e+03  4687.000000  4687.000000
# mean   1.344936e+06     4.559633     0.049925
# std    7.926258e+05     2.551019     0.217814
# min    3.700000e+01     1.000000     0.000000
# 25%    8.051900e+05     2.000000     0.000000
# 50%    1.637566e+06     4.000000     0.000000
# 75%    1.664808e+06     6.000000     0.000000
# max    4.062897e+06    12.000000     1.000000

# %%
df.sort_values(by='Sale_made',ascending=False)
# Out:
#       Customer_ID  result_rank provider_Nm  product_name dummy_quote_value  \
# 4253      1681285            5  Provider A    Product 84           454.001
# 511        288196            3  Provider A    Product 64           1297.08
# 3408      1662107            1  Provider A  Product 3292           84.8214
# 4363      1683353            3  Provider A  Product 3160           689.825
# 610        288321            1  Provider B  Product 1412           590.039
# 2288      1635814            1  Provider B  Product 3532           408.374
# 3095      1656350            2  Provider A    Product 64           48.3169
# 158           271            1  Provider A  Product 3160           134.563
# 2156      1631314            2  Provider A    Product 64            254.14
# 607        288320            8  Provider A    Product 76           294.399
# 2712      1646735            3  Provider A   Product 552           908.916
# 4250      1681285            2  Provider A    Product 56           266.794
# 902        288626            1  Provider B  Product 3164           552.593
# 257           330            7  Provider B  Product 1412           6974.01
# 165           272            1  Provider A  Product 3160           451.541
# 3944      1673545            3  Provider A    Product 56           1.99764
# 600        288320            1  Provider B  Product 3532           14.0676
# 1498      1325198            1  Provider A    Product 56           650.073
# 2558      1642321            3  Provider A   Product 552           3.11825
# 352        288054            5  Provider A   Product 552           569.813
# 4245      1681220            5  Provider A    Product 76           807.128
# 4537      3729843            1  Provider B  Product 3532           576.373
# 350        288054            3  Provider A  Product 3160           926.687
# 175           275            1  Provider A  Product 3160           142.475
# 176           275            2  Provider A  Product 3292           310.658
# 595        288308            2  Provider A    Product 56           4.84622
# 4372      1683379            6  Provider B  Product 3532           26.1079
# 4187      1679695            5  Provider A   Product 552           600.428
# 2912      1651696            3  Provider B  Product 1412           695.202
# 1387      1321181            7  Provider A    Product 88           115.598
# ...           ...          ...         ...           ...               ...
# 1620      1327927           10  Provider B  Product 3164           685.484
# 1619      1327927            9  Provider A    Product 84           665.838
# 1618      1327927            8  Provider A    Product 76           359.892
# 1617      1327927            7  Provider B  Product 1412           303.992
# 1615      1327927            5  Provider A    Product 56           65.3603
# 1642      1337193            1  Provider A  Product 3160           79.0693
# 1614      1327927            4  Provider A    Product 64           348.718
# 1613      1327927            3  Provider A  Product 3292           94.1589
# 1612      1327927            2  Provider B  Product 3532           471.044
# 1611      1327927            1  Provider A  Product 3160           479.191
# 1610      1327868           10  Provider B  Product 3164           593.871
# 1609      1327868            9  Provider B  Product 1412           808.555
# 1623      1336113            3  Provider A    Product 64           88.4959
# 1624      1336113            4  Provider A    Product 56           465.065
# 1625      1336113            5  Provider A   Product 552           465.741
# 1626      1336113            6  Provider A    Product 72           111.471
# 1627      1336113            7  Provider A    Product 76           245.719
# 1628      1336113            8  Provider A    Product 84           470.284
# 1629      1336113            9  Provider B  Product 1412           292.468
# 1630      1336113           10  Provider B  Product 3164           129.095
# 1632      1337186            1  Provider A    Product 64           472.992
# 1633      1337186            2  Provider A    Product 56           535.796
# 1634      1337186            3  Provider A   Product 552           19.8884
# 1635      1337186            4  Provider A    Product 76           677.601
# 1636      1337186            5  Provider A    Product 68           280.804
# 1637      1337186            6  Provider A    Product 60           80.6543
# 1638      1337186            7  Provider A    Product 88           536.751
# 1639      1337186            8  Provider A    Product 84           475.914
# 1640      1337186            9  Provider B  Product 1412           233.188
# 4686      4062897            7  Provider B  Product 3164           693.729
#
#       Sale_made Sale_source
# 4253          1  callcentre
# 511           1      online
# 3408          1  callcentre
# 4363          1  callcentre
# 610           1      online
# 2288          1  callcentre
# 3095          1  callcentre
# 158           1      online
# 2156          1      online
# 607           1      online
# 2712          1  callcentre
# 4250          1  callcentre
# 902           1      online
# 257           1  callcentre
# 165           1      online
# 3944          1      online
# 600           1      online
# 1498          1      online
# 2558          1      online
# 352           1  callcentre
# 4245          1  callcentre
# 4537          1      online
# 350           1  callcentre
# 175           1      online
# 176           1      online
# 595           1      online
# 4372          1  callcentre
# 4187          1  callcentre
# 2912          1  callcentre
# 1387          1      online
# ...         ...         ...
# 1620          0         NaN
# 1619          0         NaN
# 1618          0         NaN
# 1617          0         NaN
# 1615          0         NaN
# 1642          0         NaN
# 1614          0         NaN
# 1613          0         NaN
# 1612          0         NaN
# 1611          0         NaN
# 1610          0         NaN
# 1609          0         NaN
# 1623          0         NaN
# 1624          0         NaN
# 1625          0         NaN
# 1626          0         NaN
# 1627          0         NaN
# 1628          0         NaN
# 1629          0         NaN
# 1630          0         NaN
# 1632          0         NaN
# 1633          0         NaN
# 1634          0         NaN
# 1635          0         NaN
# 1636          0         NaN
# 1637          0         NaN
# 1638          0         NaN
# 1639          0         NaN
# 1640          0         NaN
# 4686          0         NaN
#
# [4687 rows x 7 columns]

# %%
df.groupby('Sale_made').count()
df.keys()
# Out:
# Index(['Customer_ID', 'result_rank', 'provider_Nm', 'product_name',
#        'dummy_quote_value', 'Sale_made', 'Sale_source'],
#       dtype='object')

# %% [markdown]
# ## 1. calculate a general converstion rate

# %%
sales_made = df[df['Sale_made'] ==1]
sales_made['Sale_made'].count()
# Out:
# 234

# %%
general_CR =sales_made['Sale_made'].count() /  len(df['Customer_ID'])

# %%
general_CR
# Out:
# 0.049925325368039258

# %% [markdown]
# ## 2. calculate top 5 prodcut conversion rate

# %%
df['product_name'].value_counts()
# Out:
# Product 84      639
# Product 552     599
# Product 1412    596
# Product 56      573
# Product 3164    486
# Product 3160    428
# Product 76      316
# Product 64      295
# Product 3292    201
# Product 3532    158
# Product 88       78
# Product 68       77
# Product 60       76
# Product 72       64
# Product 80       59
# Product 0        42
# Name: product_name, dtype: int64

# %%
product_sele = df[['product_name', 'Sale_made']].groupby('product_name').agg(['count'])
sales_made_byproduct = df[df['Sale_made'] ==1]
sales_made_byproduct[['product_name', 'Sale_made']].groupby('product_name').agg(['count'])
# Out:
#              Sale_made
#                  count
# product_name
# Product 0            7
# Product 1412        26
# Product 3160        41
# Product 3164        11
# Product 3292        12
# Product 3532        17
# Product 552         23
# Product 56          43
# Product 64          20
# Product 68           5
# Product 76           8
# Product 80           5
# Product 84          14
# Product 88           2

# %%
byproduct_pd = df.groupby('product_name')
product_sale = byproduct_pd['Sale_made'].agg({'occurance':'count', 'sales': 'sum'}).reset_index()

# %%
product_sale['CR']=product_sale.apply(lambda row: (row['sales']/ row['occurance']), axis=1)

# %%
sorted_productCR = product_sale.sort_values(by='CR',ascending=False)
sorted_productCR
# Out:
#     product_name  occurance  sales        CR
# 0      Product 0         42      7  0.166667
# 5   Product 3532        158     17  0.107595
# 2   Product 3160        428     41  0.095794
# 13    Product 80         59      5  0.084746
# 7     Product 56        573     43  0.075044
# 9     Product 64        295     20  0.067797
# 10    Product 68         77      5  0.064935
# 4   Product 3292        201     12  0.059701
# 1   Product 1412        596     26  0.043624
# 6    Product 552        599     23  0.038397
# 15    Product 88         78      2  0.025641
# 12    Product 76        316      8  0.025316
# 3   Product 3164        486     11  0.022634
# 14    Product 84        639     14  0.021909
# 8     Product 60         76      0  0.000000
# 11    Product 72         64      0  0.000000

# %%
threshold = general_CR
ax = sorted_productCR[['CR']].plot(kind='bar', title ="Conversion Rate",figsize=(15,10),
                                   legend=True, fontsize=12,color = 'orange')
plt.axhline(linewidth=2, color='r',y=threshold)
ax.set_xlabel("Product",fontsize=12)
ax.set_ylabel("rate",fontsize=12)
ax.set_xticklabels(sorted_productCR['product_name'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-243-a39fa1b119c5> in <module>()
#       3                                    legend=True, fontsize=12,color = 'orange')
#       4 plt.axhline(linewidth=2, color='r',y=threshold)
# ----> 5 plt.axhline.set_dashes(dashes)
#       6 ax.set_xlabel("Product",fontsize=12)
#       7 ax.set_ylabel("rate",fontsize=12)
#
# AttributeError: 'function' object has no attribute 'set_dashes'

# %% [markdown]
# ## 3. calculate conversion rate by different source (callcenter / online)

# %%
#no sales was made when the sale_source is null 
#df_fillnull = df.fillna('missing')
#df_fillnull
bysource_pd = df.groupby('Sale_source')
bysource_pd_sale = bysource_pd['Sale_made'].agg({'sales': 'sum'}).reset_index()
bysource_pd_sale
# Out:
#   Sale_source  sales
# 0  callcentre    113
# 1      online    121

# %%
bysource_pd_sale['CR']=bysource_pd_sale.apply(lambda row: (row['sales']/4687), axis=1)

# %%
bysource_pd_sale
# Out:
#   Sale_source  sales        CR
# 0  callcentre    113  0.024109
# 1      online    121  0.025816

# %%
ax = bysource_pd_sale[['CR']].plot(kind='bar', title ="Conversion",figsize=(10,10),legend=True, fontsize=12,color = 'orange')
plt.axhline(linewidth=2, color='r',y=threshold)
ax.set_xlabel("Scource",fontsize=12)
ax.set_ylabel("Rate",fontsize=12)
ax.set_xticklabels(bysource_pd_sale['Sale_source'])
plt.show()

# %% [markdown]
# ## 4. calculate conversion rate by # prodcut recommended

# %% [markdown]
# Find the relationship between the #of prodcut system recommend to user, and the user actually brought the product

# %%
#product_sele = df[['product_name', 'Sale_made','Customer_ID']].groupby('Customer_ID').agg(['count'])
#df['Customer_ID'].nunique()
bycustomer_pd = df.groupby('Customer_ID')
bycustomer_sale = bycustomer_pd['Sale_made'].agg({'occurance':'count', 'sales': 'sum'}).reset_index()
bycustomer_sale['CR']=bycustomer_sale.apply(lambda row: (row['sales']/ row['occurance']), axis=1)
bycustomer_sale = bycustomer_sale.sort_values(by='occurance',ascending=False)
bycustomer_sale
# Out:
#      Customer_ID  occurance  sales        CR
# 448      1661666         16      2  0.125000
# 594      1685822         14      4  0.285714
# 337      1641827         12      0  0.000000
# 496      1668648         12      0  0.000000
# 478      1665782         12      0  0.000000
# 273      1629520         12      1  0.083333
# 145       289223         12      2  0.166667
# 315      1637948         12      0  0.000000
# 136       288778         12      0  0.000000
# 435      1659907         12      0  0.000000
# 15           260         12      2  0.166667
# 562      1679987         12      1  0.083333
# 7            205         12      1  0.083333
# 571      1681291         12      1  0.083333
# 604      2862744         11      1  0.090909
# 319      1639262         11      1  0.090909
# 163       885161         11      2  0.181818
# 284      1631314         11      1  0.090909
# 354      1644813         11      0  0.000000
# 111       288594         11      0  0.000000
# 506      1670528         10      0  0.000000
# 208      1327737         10      0  0.000000
# 204      1326735         10      1  0.100000
# 202      1326551         10      0  0.000000
# 525      1673355         10      0  0.000000
# 200      1326170         10      0  0.000000
# 196      1324761         10      0  0.000000
# 186      1321866         10      0  0.000000
# 211      1327868         10      1  0.100000
# 185      1321430         10      0  0.000000
# ..           ...        ...    ...       ...
# 135       288777          2      1  0.500000
# 292      1632781          2      0  0.000000
# 524      1673214          2      0  0.000000
# 293      1633357          2      0  0.000000
# 120       288627          2      0  0.000000
# 558      1678656          2      1  0.500000
# 304      1636075          2      1  0.500000
# 311      1637653          2      0  0.000000
# 316      1638534          2      0  0.000000
# 102       288543          2      0  0.000000
# 266      1628474          2      0  0.000000
# 58        288130          2      2  1.000000
# 514      1671387          2      0  0.000000
# 88        288391          1      0  0.000000
# 43        288034          1      1  1.000000
# 535      1674517          1      0  0.000000
# 537      1674881          1      0  0.000000
# 166      1318062          1      0  0.000000
# 483      1666712          1      0  0.000000
# 474      1665369          1      0  0.000000
# 240      1618890          1      0  0.000000
# 426      1658465          1      0  0.000000
# 179      1320668          1      1  1.000000
# 490      1668094          1      0  0.000000
# 214      1336802          1      1  1.000000
# 356      1645634          1      0  0.000000
# 195      1324609          1      0  0.000000
# 359      1646246          1      0  0.000000
# 271      1629367          1      0  0.000000
# 46        288052          1      0  0.000000
#
# [628 rows x 4 columns]

# %%
bycustomer_sale.plot(kind='scatter', x='occurance', y='CR', c='sales',figsize=(13,8),s=bycustomer_sale['sales']*200, cmap='Oranges');

# %% [markdown]
# ## 4. calculate conversion rate by different source (callcenter / online)
